# %% [markdown]
# <a href="https://colab.research.google.com/github/JAYTRIVEDI2510/JAYTRIVEDI2510/blob/ASSIGNMENTS/Assignment_1_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 7

# %%
import pandas as pd

# %%
#Importing Dataset
a=pd.read_csv("Q7.csv")
a
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
Describe=a.describe()

# %%
a.mean()      #mean
# Out:
# <ipython-input-79-2bfd785d034e>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.mean()      #mean
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
a.median()     # median
# Out:
# <ipython-input-80-0d77780ca47a>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.median()     # median
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
a.mode()     # mode
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0           AMC Javelin    3.07   3.44  17.02
# 1    Cadillac Fleetwood    3.92    NaN  18.90
# 2            Camaro Z28     NaN    NaN    NaN
# 3     Chrysler Imperial     NaN    NaN    NaN
# 4            Datsun 710     NaN    NaN    NaN
# 5      Dodge Challenger     NaN    NaN    NaN
# 6            Duster 360     NaN    NaN    NaN
# 7          Ferrari Dino     NaN    NaN    NaN
# 8              Fiat 128     NaN    NaN    NaN
# 9             Fiat X1-9     NaN    NaN    NaN
# 10       Ford Pantera L     NaN    NaN    NaN
# 11          Honda Civic     NaN    NaN    NaN
# 12       Hornet 4 Drive     NaN    NaN    NaN
# 13    Hornet Sportabout     NaN    NaN    NaN
# 14  Lincoln Continental     NaN    NaN    NaN
# 15         Lotus Europa     NaN    NaN    NaN
# 16        Maserati Bora     NaN    NaN    NaN
# 17            Mazda RX4     NaN    NaN    NaN
# 18        Mazda RX4 Wag     NaN    NaN    NaN
# ...

# %%
a.var()     # variance
# Out:
# <ipython-input-82-d8a329f50ece>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.var()     # variance
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
a.std()       # standerd deviaton
# Out:
# <ipython-input-83-d995075a4d51>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.std()       # standerd deviaton
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
# find range

Range=Describe.loc["max"]-Describe.loc["min"]
Range
# Out:
# Points    2.170
# Score     3.911
# Weigh     8.400
# dtype: float64

# %% [markdown]
# #Question 9 a

# %%
import pandas as pd

import numpy as np

# %%
#Importing Dataset
b=pd.read_csv("Q9_a.csv")
b
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
from scipy.stats import skew
from scipy.stats import kurtosis

# %%
print(skew(b,axis=0,bias=True))
# Out:
# [ 0.         -0.11395477  0.78248352]

# %%
print(kurtosis(b,axis=0,bias=True))
# Out:
# [-1.20096038 -0.57714742  0.24801866]

# %% [markdown]
# #Question 9 B

# %%
#Importing Dataset
c=pd.read_csv("Q9_a.csv")
c
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
print(skew(c,axis=0,bias=True))
# Out:
# [ 0.         -0.11395477  0.78248352]

# %%
print(skew(c,axis=0,bias=True))
# Out:
# [ 0.         -0.11395477  0.78248352]

# %% [markdown]
# #Question 11

# %%
from scipy import stats
import numpy as np

# %%
#sample statistics
sample_mean = 200
sample_std = 30
sample_size = 2000

#Degrees Of Freedom
df = sample_size - 1

#Critical values for different level of confidence
t_94 = stats.t.ppf(0.97,df)
t_98 = stats.t.ppf(0.99,df)
t_96 = stats.t.ppf(0.99,df)

#Confidence intervals
ci_94 = (sample_mean - t_94 * sample_std / np.sqrt(sample_size))
ci_98 = (sample_mean - t_98 * sample_std / np.sqrt(sample_size))
ci_96 = (sample_mean - t_96 * sample_std / np.sqrt(sample_size))

#print the results
print("94% Confidence Interval:",ci_94)
print("98% Confidence Interval:",ci_98)
print("96% Confidence Interval:",ci_96)
# Out:
# 94% Confidence Interval: 198.7376089443071
# 98% Confidence Interval: 198.4381860483216
# 96% Confidence Interval: 198.4381860483216

# %% [markdown]
# #Question 12

# %%
Q12=[34,36,38,38,39,40,40,41,41,41,41,42,42,45,49,56]

# %%
print(np.average(Q12))
print(np.median(Q12))
print(np.var(Q12))
print(np.std(Q12))
# Out:
# 41.4375
# 41.0
# 25.12109375
# 5.0120947467102015

# %% [markdown]
# #Question 20

# %%
cars=pd.read_csv("Cars.csv")
cars
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
from scipy import stats

# %%
mpg=cars["MPG"]
mpg
# Out:
# 0     53.700681
# 1     50.013401
# 2     50.013401
# 3     45.696322
# 4     50.504232
#         ...
# 76    36.900000
# 77    19.197888
# 78    34.000000
# 79    19.833733
# 80    12.101263
# Name: MPG, Length: 81, dtype: float64

# %%
from numpy.ma.core import std
# a.	P(MPG>38)
(30-mpg.mean())/mpg.std()
# Out:
# -0.48426901305407655

# %%
probality =1-stats.norm.cdf(-0.48426901305407655,mpg.mean(),mpg.std())
probality*100
# Out:
# 99.99339882499974

# %%
# b.	P(MPG<40)
(40-mpg.mean())/mpg.std()
# Out:
# 0.6108479474833596

# %%
probality =stats.norm.cdf(0.6108479474833596,mpg.mean(),mpg.std())
probality*100
# Out:
# 0.010664806656969663

# %%
#C.P (20<MPG<50)

print((20-mpg.mean())/mpg.std())
print((50-mpg.mean())/mpg.std())
# Out:
# -1.5793859735915128
# 1.7059649080207957

# %%
probality = stats.norm.cdf(1.7059649080207957,mpg.mean(),mpg.std())-stats.norm.cdf(-1.5793859735915128,mpg.mean(),mpg.std())
probality*100
# Out:
# 0.01296628446547641

# %% [markdown]
# #Question 21

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.median()
# Out:
# HP     100.000000
# MPG     35.152727
# VOL    101.000000
# SP     118.208698
# WT      32.734518
# dtype: float64

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
qqplotqplot=sm.qqplot(mpg,line="q")
plt.title("normal")
plt.show()

# %%
# Q-21 (b)

wc = pd.read_csv("wc-at.csv")
wc
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(wc["Waist"],line="q")
plt.title("normal")
plt.show()

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(wc["AT"],line="q")
plt.title("normal")
plt.show()

# %% [markdown]
# #Question 24

# %%
from scipy import stats
import numpy as np

null_mean = 270

alt_mean = 260

n = 18
sample_mean = 260
sample_std = 90

# Calculate the t-score
t = (sample_mean - null_mean) / (sample_std / np.sqrt(n))

# Find the p-value from the t-distribution
df = n - 1
p_value = stats.t.cdf(t, df)

print("The p-value is:", p_value)
# Out:
# The p-value is: 0.32167253567098364
